# %%
import numpy as np
import sympy as sp
import matplotlib.pyplot as plt

# %%
# Define the equation as a symbolic expression
x = sp.symbols('x')
equation = x**3 - 5*x + 1
iterations = [0]

# %%
def eq_function(x_value):
    result=equation.subs(x, x_value)
    return result

# %%
def secant(x1,x2,max_iterations,tolearance):
    x_values = [x1,x2]
    
    for i in range(max_iterations):
        x3 = (x1*eq_function(x2) - x2*eq_function(x1))/(eq_function(x2)-eq_function(x1))
        print(f"Result Of x in each iteration : {x3}")
        x_values.append(x3)
        iterations.append(i + 1)
        if abs(x2 - x1) < tolerance:
            break
        x1 = x2
        x2 = x3
        
    return x_values, iterations

# %%
x1 = 0
x2 = 1
max_iterations = 100  # Example: Change this to an integer value
tolerance = 1e-6

x_values, iterations = secant(x1, x2, max_iterations, tolerance)
# Out:
# Result Of x in each iteration : 1/4
# Result Of x in each iteration : 11/59
# Result Of x in each iteration : 54563/270467
# Result Of x in each iteration : 250925689837487/1244425078869458
# Result Of x in each iteration : 10129502880982330269092892333244979820343/50235663416677453076442162006445178047387
# Result Of x in each iteration : 3843985457224111987475777403053471140401513172262936376045912238390459815346852053076846205005688766097940335433/19063636377282340724806131832179590902069472716657159236530525578592451452302788658202836565998191979736154829697

# %%
# Plot the convergence
iterations = list(range(len(x_values)))
plt.plot(iterations, x_values, marker='o', linestyle='-')
plt.xlabel("Iterations")
plt.ylabel("x")
plt.title("Secant Method Convergence")
plt.grid(True)
plt.show()
